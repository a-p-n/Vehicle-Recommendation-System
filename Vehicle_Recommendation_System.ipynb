# %% [markdown]
# <a href="https://colab.research.google.com/github/a-p-n/Vehicle-Recommendation-System/blob/main/Vehicle_Recommendation_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv('vehicles_dataset.csv')
data.columns
# Out:
# Index(['name', 'description', 'make', 'model', 'type', 'year', 'price',
#        'engine', 'cylinders', 'fuel', 'mileage', 'transmission', 'trim',
#        'body', 'doors', 'exterior_color', 'interior_color', 'drivetrain'],
#       dtype='object')

# %% [markdown]
# Important columns -> Make, Type, Price, Mileage, Fuel, Body, Year

# %%
new_data = data[['make', 'price', 'mileage', 'fuel', 'body', 'year', 'transmission']]
new_data
# Out:
#                make    price  mileage      fuel          body  year  \
# 0              Jeep  74600.0     10.0  Gasoline           SUV  2024
# 1              Jeep  50170.0      1.0  Gasoline           SUV  2024
# 2               GMC  96410.0      0.0  Gasoline           SUV  2024
# 3             Dodge  46835.0     32.0  Gasoline           SUV  2023
# 4               RAM  81663.0     10.0    Diesel  Pickup Truck  2024
# ...             ...      ...      ...       ...           ...   ...
# 997   Mercedes-Benz  59037.0     10.0    Diesel     Cargo Van  2024
# 998           Dodge  49720.0      0.0  Gasoline           SUV  2024
# 999            Jeep  69085.0     20.0  Gasoline           SUV  2024
# 1000         Nissan  43495.0      6.0  Gasoline           SUV  2024
# 1001      Chevrolet  48995.0     31.0  Gasoline  Pickup Truck  2024
#
#                              transmission
# 0                       8-Speed Automatic
# 1                       8-Speed Automatic
# ...
